# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 50%, #00897b 100%); padding: 28px 32px; border-radius: 16px; color: #ffffff; margin-bottom: 22px; box-shadow: 0 10px 28px rgba(0, 77, 64, 0.35); border: 1px solid rgba(255, 255, 255, 0.15);">
#   <div style="display: flex; align-items: center; justify-content: space-between; flex-wrap: wrap; gap: 14px;">
#     <div>
#       <span style="background: rgba(255, 255, 255, 0.2); padding: 5px 14px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1.2px; display: inline-block; margin-bottom: 10px;">
#         Portfolio Python • Pandas • NumPy Project
#       </span>
#       <h1 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, BlinkMacSystemFont, Roboto, sans-serif; font-size: 32px; font-weight: 800; letter-spacing: -0.5px;">
#         📦 Brazilian E-Commerce Data Analysis using Python & Pandas
#       </h1>
#       <p style="margin: 10px 0 0 0; color: #e0f2f1; font-size: 15px; max-width: 740px; line-height: 1.6;">
#         End-to-End Enterprise Data Wrangling, Statistical Profiling, Outlier Detection, RFM Segmentation, and Business Analytics on the Olist Brazilian E-Commerce Dataset — strictly powered by <b>Python, Pandas & NumPy</b>.
#       </p>
#     </div>
#     <div style="display: flex; align-items: center;">
#       <a href="https://colab.research.google.com/github/DebarghyaAich/Machine_Learning_Basics/blob/main/Python_Libraries_Tutorial/E-Commerce%20Feature%20Extraction.ipynb" target="_blank">
#         <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" style="height: 34px; filter: drop-shadow(0 2px 6px rgba(0,0,0,0.25));" />
#       </a>
#     </div>
#   </div>
#   <div style="margin-top: 18px; padding-top: 14px; border-top: 1px solid rgba(255, 255, 255, 0.22); display: flex; gap: 20px; font-size: 12px; color: #b2dfdb; flex-wrap: wrap; font-weight: 500;">
#     <span>⚡ <b>Kernel:</b> Python 3.12 (ML Basics)</span>
#     <span>🛠️ <b>Tech Stack:</b> Python • Pandas • NumPy • Google Colab</span>
#     <span>🚫 <b>Pure Data Analytics:</b> Zero SQL • Zero Visualization Dependencies</span>
#     <span>🎯 <b>Scope:</b> 26 Comprehensive Parts (A–Z) & 77 Hands-On Questions</span>
#   </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART A
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>📂</span> Dataset Understanding
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Survey the available data files, columns, and analytical domain scope before writing code.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q1: Identify All Available Datasets <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Python lists, os, file handling, Pandas</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Inspect the Olist CSV files available in the directory. Identify each file name, determine its total number of columns, and document its business purpose.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Dataset | Number of Columns | Purpose (Customers, Orders, Order Items, Payments, Reviews, Products, Sellers, Geolocation, Category Translation)</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Use os.listdir('data/olist') or glob.glob to inspect filenames and pd.read_csv(nrows=0).columns
#   </div>
# </div>

# %%
# Q1: Identify all available datasets
# Write your solution using Python / Pandas / NumPy below:
# Inspect files and summarize names, column counts, and purposes

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART B
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>📥</span> Loading the CSV Files
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Load all 9 Olist CSV datasets into memory as Pandas DataFrames and verify integrity.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q2: Load All CSV Files into Pandas DataFrames <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">pd.read_csv(), DataFrame</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Read the 9 Kaggle CSV files directly into Python using Pandas. Assign them to standard variable names: <code>customers, orders, order_items, payments, reviews, products, sellers, geolocation, category_translation</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>9 loaded DataFrame variables</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> The cell below extracts and initializes all DataFrames.
#   </div>
# </div>

# %%
# =============================================================================
# DATA EXTRACTION & ENVIRONMENT SETUP
# Automatically loads all 9 CSV files into standalone Pandas DataFrames.
# =============================================================================

import os
import glob
import pandas as pd
import numpy as np

# 1. Resolve dataset directory
DATA_DIR = os.path.join('data', 'olist')

# Check relative path or parent path for flexibility in any environment/Colab
if not os.path.exists(DATA_DIR) or not os.listdir(DATA_DIR):
    if os.path.exists(os.path.join('..', 'data', 'olist')):
        DATA_DIR = os.path.join('..', 'data', 'olist')
    else:
        try:
            import kagglehub
            print('Downloading Olist Brazilian E-Commerce dataset via kagglehub...')
            DATA_DIR = kagglehub.dataset_download('olistbr/brazilian-ecommerce')
        except Exception as err:
            print(f'Please ensure Olist CSV files are present in data/olist/: {err}')

print(f'Reading CSV files from: {os.path.abspath(DATA_DIR)}\n')

# 2. Load all 9 CSV files into Pandas DataFrames
customers = pd.read_csv(os.path.join(DATA_DIR, 'olist_customers_dataset.csv'))
orders = pd.read_csv(os.path.join(DATA_DIR, 'olist_orders_dataset.csv'))
order_items = pd.read_csv(os.path.join(DATA_DIR, 'olist_order_items_dataset.csv'))
payments = pd.read_csv(os.path.join(DATA_DIR, 'olist_order_payments_dataset.csv'))
reviews = pd.read_csv(os.path.join(DATA_DIR, 'olist_order_reviews_dataset.csv'))
products = pd.read_csv(os.path.join(DATA_DIR, 'olist_products_dataset.csv'))
sellers = pd.read_csv(os.path.join(DATA_DIR, 'olist_sellers_dataset.csv'))
geolocation = pd.read_csv(os.path.join(DATA_DIR, 'olist_geolocation_dataset.csv'))
category_translation = pd.read_csv(os.path.join(DATA_DIR, 'product_category_name_translation.csv'))

dfs = {
    'Customers': customers,
    'Orders': orders,
    'Order Items': order_items,
    'Payments': payments,
    'Reviews': reviews,
    'Products': products,
    'Sellers': sellers,
    'Geolocation': geolocation,
    'Category Translation': category_translation
}

print('=' * 65)
print(f"{'Dataset':<24} | {'Rows':<14} | {'Columns':<8} | {'Empty?':<6}")
print('=' * 65)
for name, df in dfs.items():
    print(f"{name:<24} | {len(df):<14,d} | {len(df.columns):<8} | {'No' if not df.empty else 'Yes'}")
print('=' * 65)
print('\n✅ All 9 datasets successfully loaded into Pandas DataFrames!')
# Out:
# Reading CSV files from: c:\Users\Debarghya2\Desktop\MACHINE_lEARNING_BASICS\data\olist
#
# ...
# Dataset                  | Rows           | Columns  | Empty?
# ...
# Customers                | 99,441         | 5        | No
# Orders                   | 99,441         | 8        | No
# Order Items              | 112,650        | 7        | No
# Payments                 | 103,886        | 5        | No
# Reviews                  | 99,224         | 7        | No
# Products                 | 32,951         | 9        | No
# Sellers                  | 3,095          | 4        | No
# Geolocation              | 1,000,163      | 5        | No
# Category Translation     | 71             | 2        | No
# ...
#
# ✅ All 9 datasets successfully loaded into Pandas DataFrames!

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q3: Verify Dataset Loading Integrity <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.shape, .empty, .head()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Confirm that every dataset was ingested correctly, has non-zero rows/columns, and is not accidentally empty.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Summary Table: Dataset | Rows | Columns | Empty? (Yes/No)</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Iterate through a dictionary of your DataFrames: {name: df} and check df.shape and df.empty
#   </div>
# </div>

# %%
# Q3: Verify that every dataset loaded correctly
# Constructing a verification summary table for all 9 loaded DataFrames

verification_records = [
    {
        'Dataset': name,
        'Rows': f"{df.shape[0]:,}",
        'Columns': df.shape[1],
        'Empty?': 'Yes' if df.empty else 'No',
        'Memory (MB)': f"{df.memory_usage(deep=True).sum() / (1024**2):.2f}"
    }
    for name, df in dfs.items()
]

verification_df = pd.DataFrame(verification_records)
verification_df
# Out:
#                 Dataset       Rows  Columns Empty? Memory (MB)
# 0             Customers     99,441        5     No       26.59
# 1                Orders     99,441        8     No       52.94
# 2           Order Items    112,650        7     No       35.99
# 3              Payments    103,886        5     No       16.23
# 4               Reviews     99,224        7     No       39.12
# 5              Products     32,951        9     No        6.30
# 6               Sellers      3,095        4     No        0.59
# 7           Geolocation  1,000,163        5     No      129.38
# 8  Category Translation         71        2     No        0.01

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART C
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🔍</span> Dataset Inspection
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Examine record samples, structural dimensions, and data types across the DataFrames.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q4: Inspect First and Last Records <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.head(), .tail()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Inspect the first 5 and last 5 records of critical datasets (orders, customers, order_items, payments).</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Display head(5) and tail(5) outputs for each dataset</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Use display(df.head()) and display(df.tail())
#   </div>
# </div>

# %%
from IPython.display import display

# Q4: Inspect the first and last records
for name, df in dfs.items():
    print(f"\n{'='*40} Table : {name} {'='*40}")
    df1 = df.head(5)
    df2 = df.tail(5)
    display(pd.concat([df1,df2],axis=0))
# Out:
# ======================================== Table : Customers ========================================
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q5: Dataset Dimensions & Column Inventory <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.shape, .columns, .info()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Produce a dataset summary table detailing the total number of rows, columns, and memory usage for all 9 DataFrames.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Summary DataFrame of dataset dimensions and column lists</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> pd.DataFrame([{'Dataset': k, 'Rows': v.shape[0], 'Cols': v.shape[1]} ...])
#   </div>
# </div>

# %%
from IPython.display import display

# Q5: Identify the structure of every dataset
# Part 1: High-Level Inventory Table
summary_df = pd.DataFrame([
    {
        'Dataset': name,
        'Rows': f"{df.shape[0]:,}",
        'Columns': df.shape[1],
        'Memory (MB)': f"{df.memory_usage(deep=True).sum() / (1024**2):.2f}",
        'Column Names': list(df.columns)
    }
    for name, df in dfs.items()
])
print("📌 High-Level Dataset Inventory & Dimensions Summary:")
display(summary_df)

# Part 2: Detailed Structure & Non-Null Counts for Every Table
print("\n" + "="*70)
print("DETAILED DATASET STRUCTURE (.info())")
print("="*70)
for name, df in dfs.items():
    print(f"\n{'='*35} Table : {name} {'='*35}")
    print(f"Shape   : {df.shape[0]:,} rows × {df.shape[1]} columns")
    print(f"Columns : {list(df.columns)}\n")
    df.info()
# Out:
# 📌 High-Level Dataset Inventory & Dimensions Summary:
#                 Dataset       Rows  Columns Memory (MB)                                                                                                                                                                        Column Names
# 0             Customers     99,441        5       26.59                                                                                          [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# 1                Orders     99,441        8       52.94      [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# ...

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q6: Data Types & Conversion Requirements <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.dtypes, .select_dtypes()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Identify the data types of each column across all datasets. Identify columns that need conversion (e.g. order timestamps to datetime, prices/freight to numeric).</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table/Dict of columns requiring datatype casting</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> orders.dtypes, order_items.dtypes
#   </div>
# </div>

# %%
# Q6: Identify the data types
for name,df in dfs.items():

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART D
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🩹</span> Missing Values Analysis
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Quantify null values, calculate missingness rates, and flag sparse columns requiring imputation or cleaning.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q7: Find Missing Values Across Datasets <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.isna().sum()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the total count of null values in every column of every dataset.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Dataset | Column | Missing Values</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> df.isna().sum()[df.isna().sum() > 0]
#   </div>
# </div>

# %%
# Q7: Find missing values in every dataset
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q8: Calculate Missing-Value Percentages <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.isna().mean() * 100</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the percentage of missing values per column to evaluate data completeness.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Column | Missing Count | Missing %</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> (df.isna().sum() / len(df) * 100).round(2)
#   </div>
# </div>

# %%
# Q8: Calculate missing-value percentages
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q9: Identify Columns with Significant Missing Data <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Conditional filtering, boolean masking</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Filter and display all columns where the missing percentage exceeds a defined threshold (e.g. 30%). Document why this threshold was chosen.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table of columns with missing % > threshold</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> missing_df[missing_df['Missing %'] > 30]
#   </div>
# </div>

# %%
# Q9: Identify columns with significant missing data
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART E
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>👥</span> Duplicate Detection
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Identify redundant rows, primary key collisions, and duplicate records across core tables.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q10: Check for Duplicate Rows <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.duplicated().sum()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Check for completely identical rows across all datasets and report the duplicate counts.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Dataset | Duplicate Rows Count</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> df.duplicated().sum() for each DataFrame
#   </div>
# </div>

# %%
# Q10: Check for duplicate rows
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q11: Duplicate Analysis in Core Datasets <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.duplicated(), value_counts()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Analyze duplicate records in key entities (Orders, Customers, Products, Sellers, Order Items). Calculate total records, duplicate count, and duplicate percentage.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Dataset | Total Records | Duplicate Records | Duplicate %</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Check both full-row duplicates and key-specific duplicates (e.g. order_id)
#   </div>
# </div>

# %%
# Q11: Identify duplicate records in important datasets
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART F
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🧹</span> Data Cleaning & Transformation
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Cast datetime columns, validate numeric constraints, and create clean DataFrame copies without altering raw data.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q12: Convert Date Columns to Datetime Format <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">pd.to_datetime()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Convert all date/timestamp columns in <code>orders</code> into proper pandas datetime objects (<code>order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date</code>).</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Verify with orders.dtypes that date columns are datetime64[ns]</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> pd.to_datetime(orders['order_purchase_timestamp'], errors='coerce')
#   </div>
# </div>

# %%
# Q12: Convert date columns into datetime format
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q13: Validate Numeric Columns for Invalid/Negative Values <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">pd.to_numeric(), (col <= 0).sum()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Audit key numerical columns (<code>price, freight_value, payment_value, payment_installments, product_weight_g, product_length_cm, product_height_cm, product_width_cm</code>) for negative values, zeroes, or anomalies.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Report of minimum values, negative count, and invalid entries per column</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Use .describe() or boolean checks like (df['price'] < 0).sum()
#   </div>
# </div>

# %%
# Q13: Check numeric columns for invalid values
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q14: Create Cleaned Versions of Important Datasets <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.copy(), documented cleaning steps</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Create clean versions of critical DataFrames (e.g. <code>orders_clean, order_items_clean, payments_clean</code>) without modifying the raw DataFrames. Document every cleaning step performed.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Clean DataFrames with confirmed data types and validated values</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> orders_clean = orders.copy() ... document cleaning rationale in comments
#   </div>
# </div>

# %%
# Q14: Create a cleaned version of the important datasets
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART G
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🧭</span> Basic Exploratory Analysis
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Calculate platform cardinality: unique customers, orders, products, and sellers.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q15: Count Unique Customers <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.nunique()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the total number of unique customers in the <code>customers</code> dataset (distinguishing <code>customer_id</code> vs <code>customer_unique_id</code>).</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Total unique customers count</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> customers['customer_unique_id'].nunique()
#   </div>
# </div>

# %%
# Q15: Count unique customers
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q16: Count Unique Orders <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.nunique()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the total number of unique orders in the <code>orders</code> dataset.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Total unique orders count</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> orders['order_id'].nunique()
#   </div>
# </div>

# %%
# Q16: Count unique orders
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q17: Count Unique Products and Sellers <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.nunique()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the total number of unique products in <code>products</code> and unique sellers in <code>sellers</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Unique products: ? | Unique sellers: ?</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> products['product_id'].nunique(), sellers['seller_id'].nunique()
#   </div>
# </div>

# %%
# Q17: Count unique products and sellers
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART H
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🔍</span> Boolean Filtering & Slicing
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Extract specific business subsets: delivered orders, canceled/unavailable orders, and premium purchases.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q18: Filter Delivered Orders <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Boolean indexing: df[df['col'] == val]</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Filter the <code>orders</code> DataFrame to isolate all orders with status <code>'delivered'</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>DataFrame containing only delivered orders</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> orders[orders['order_status'] == 'delivered']
#   </div>
# </div>

# %%
# Q18: Find all delivered orders
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q19: Analyze Canceled & Unavailable Orders <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.isin(), .value_counts(normalize=True)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the total count and percentage of orders that were canceled or unavailable relative to total orders.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Canceled count, Unavailable count, and % of total orders</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> orders['order_status'].isin(['canceled', 'unavailable'])
#   </div>
# </div>

# %%
# Q19: Find canceled and unavailable orders
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q20: Filter High-Value Order Items <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Boolean filtering, quantile threshold</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Define a reasonable monetary threshold for 'high-value' items (e.g. price > 500 or 95th percentile) and filter <code>order_items</code>. Explain and justify your chosen threshold.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Filtered DataFrame of high-value items + threshold explanation</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> threshold = order_items['price'].quantile(0.95); order_items[order_items['price'] > threshold]
#   </div>
# </div>

# %%
# Q20: Find high-value order items
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART I
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🔀</span> Sorting & Ranking
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Identify extreme values: highest-priced products and most expensive shipping charges.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q21: Top 10 Most Expensive Products/Items <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.sort_values(by='price', ascending=False).head(10)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Sort <code>order_items</code> by <code>price</code> in descending order and display the top 10 highest-priced items.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Top 10 rows with product_id, price, and order_id</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_items.sort_values(by='price', ascending=False)[['order_id', 'product_id', 'price']].head(10)
#   </div>
# </div>

# %%
# Q21: Find the most expensive products/items
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q22: Top 10 Most Expensive Shipping Charges <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.sort_values(by='freight_value', ascending=False).head(10)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Sort <code>order_items</code> by <code>freight_value</code> in descending order and return the top 10 records.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Top 10 records by freight_value</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_items.sort_values(by='freight_value', ascending=False)[['order_id', 'product_id', 'freight_value']].head(10)
#   </div>
# </div>

# %%
# Q22: Find the most expensive shipping charges
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART J
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>📊</span> GroupBy & Aggregations
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Aggregate orders by status, compute revenue, and calculate true Average Order Value (AOV).</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q23: Order Count by Status <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.groupby('order_status').size() or .value_counts()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Group orders by <code>order_status</code> and count the total orders in each status category.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Status | Orders</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> orders['order_status'].value_counts()
#   </div>
# </div>

# %%
# Q23: Count orders by status
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q24: Order Status Percentages <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">value_counts(normalize=True) * 100</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the percentage distribution of each order status relative to total platform orders.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Status | Orders | Percentage</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> pd.DataFrame({'Count': orders['order_status'].value_counts(), 'Pct': orders['order_status'].value_counts(normalize=True)*100})
#   </div>
# </div>

# %%
# Q24: Calculate order-status percentages
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q25: Total Revenue Generated <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.sum() on payment_value</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the total cumulative revenue generated across all payments.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Total Revenue = $X,XXX,XXX.XX</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> payments['payment_value'].sum()
#   </div>
# </div>

# %%
# Q25: Calculate total revenue
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q26: Average Order Value (AOV) <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.groupby('order_id')['payment_value'].sum().mean()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the average amount paid per distinct order. Ensure payments are first aggregated per order_id before calculating the mean.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Average Order Value = $XXX.XX</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_totals = payments.groupby('order_id')['payment_value'].sum(); order_totals.mean()
#   </div>
# </div>

# %%
# Q26: Calculate average order value
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART K
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>👤</span> Customer Analysis
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Identify repeat buyers, top purchasers by order volume, and top spenders.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q27: Find Customers with Multiple Orders <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">merge, groupby, count, filter > 1</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Identify customers who have placed more than 1 order using <code>customer_unique_id</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Customer | Number of Orders (filtered for > 1)</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> cust_orders = orders.merge(customers, on='customer_id').groupby('customer_unique_id').size(); cust_orders[cust_orders > 1]
#   </div>
# </div>

# %%
# Q27: Find customers with multiple orders
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q28: Top 10 Customers by Order Volume <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.value_counts().head(10)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Find the top 10 customers based on the total count of orders placed.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Ranked table: customer_unique_id | order_count</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> cust_orders.sort_values(ascending=False).head(10)
#   </div>
# </div>

# %%
# Q28: Find the top 10 customers based on the number of orders
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q29: Top 10 Customers by Total Spending <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">merge, groupby('customer_unique_id')['payment_value'].sum()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Find the top 10 customers based on total monetary spend. Requires merging customers, orders, and payments.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Ranked table: customer_unique_id | total_spending</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> merge customers -> orders -> payments, groupby unique_id, sum payment_value, head(10)
#   </div>
# </div>

# %%
# Q29: Find the top 10 customers based on total spending
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART L
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🔗</span> Pandas Merging & Master Dataset Creation
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Join relational tables to construct a consolidated master analytical DataFrame.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q30: Merge Customers and Orders <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">pd.merge(how='inner', on='customer_id')</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Merge the <code>customers</code> and <code>orders</code> DataFrames on <code>customer_id</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Combined DataFrame: customer_orders</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> pd.merge(orders, customers, on='customer_id', how='inner')
#   </div>
# </div>

# %%
# Q30: Merge customers and orders
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q31: Merge Orders with Payments <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">pd.merge(how='inner', on='order_id')</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Merge the <code>orders</code> and <code>payments</code> DataFrames on <code>order_id</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Combined DataFrame: order_payments_df</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> pd.merge(orders, payments, on='order_id', how='inner')
#   </div>
# </div>

# %%
# Q31: Merge orders with payments
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q32: Create a Master Sales Dataset <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Sequential pd.merge() with join validation</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Create a single consolidated, analysis-ready DataFrame by merging: Customers, Orders, Order Items, Products, Payments, and Sellers.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>master_df with shape and preview</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Start with orders -> merge customers -> order_items -> products -> payments -> sellers
#   </div>
# </div>

# %%
# Q32: Create a master sales dataset
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART M
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🏷️</span> Product & Category Analysis
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Determine bestselling items, product revenue, top categories, and average category prices.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q33: Top 10 Most Frequently Purchased Products <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.value_counts().head(10)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Find the 10 most frequently purchased products based on total items sold in <code>order_items</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Product ID | Purchase Count</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_items['product_id'].value_counts().head(10)
#   </div>
# </div>

# %%
# Q33: Find the most frequently purchased products
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q34: Calculate Total Revenue by Product <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">groupby('product_id')['price'].sum().sort_values(ascending=False)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the total revenue generated by each product (sum of item prices). Return the top 10 products.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Top 10 Products by Revenue</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_items.groupby('product_id')['price'].sum().sort_values(ascending=False).head(10)
#   </div>
# </div>

# %%
# Q34: Calculate product revenue
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q35: Top Revenue Generating Product Categories <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">merge, groupby('category')['price'].sum()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Merge products, category_translation, and order_items to find the product categories that generated the highest total revenue.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Category | Revenue | % of Total</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Merge products with category_translation on product_category_name
#   </div>
# </div>

# %%
# Q35: Identify the highest-revenue product categories
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q36: Average Product Price by Category <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">groupby('category')['price'].mean()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the average product price for each product category.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Category | Average Price</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_items.merge(products).groupby('product_category_name')['price'].mean().sort_values(ascending=False)
#   </div>
# </div>

# %%
# Q36: Calculate average product price by category
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART N
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🏬</span> Seller Analysis
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Evaluate marketplace sellers, order distribution, merchant revenue, and seller fulfillment scale.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q37: Count Orders Handled by Each Seller <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.value_counts().head(10)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Count total order items fulfilled by each seller in <code>order_items</code>. Display the top 10 sellers.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Top Sellers by Item Volume</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_items['seller_id'].value_counts().head(10)
#   </div>
# </div>

# %%
# Q37: Count orders handled by each seller
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q38: Calculate Seller Revenue <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">groupby('seller_id')['price'].sum().sort_values(ascending=False)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the total gross merchandise revenue generated by each seller. Display the top 10 sellers.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Seller | Revenue</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_items.groupby('seller_id')['price'].sum().sort_values(ascending=False).head(10)
#   </div>
# </div>

# %%
# Q38: Calculate seller revenue
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q39: Average Selling Price by Seller <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">groupby('seller_id')['price'].mean()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the average price of items sold by each seller.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Seller ID | Average Item Price</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_items.groupby('seller_id')['price'].mean()
#   </div>
# </div>

# %%
# Q39: Calculate average selling price by seller
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART O
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>💳</span> Payment & Transaction Analysis
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Examine payment method distributions, installment statistics, and value breakdowns.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q40: Analyze Payment Methods <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">groupby('payment_type').agg()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">For each payment method, calculate: transaction count, total payment value, average payment value, and percentage share.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Payment Type | Transactions | Total | Average | % Share</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> payments.groupby('payment_type').agg(Count=('payment_value', 'count'), Total=('payment_value', 'sum'), Avg=('payment_value', 'mean'))
#   </div>
# </div>

# %%
# Q40: Analyze payment methods
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q41: Analyze Payment Installments <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">NumPy & Pandas descriptive methods: .min(), .max(), .mean(), .median(), .std()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate descriptive statistics for payment installments: min, max, mean, median, and standard deviation.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Statistical Summary Table of Installments</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> payments['payment_installments'].agg(['min', 'max', 'mean', 'median', 'std'])
#   </div>
# </div>

# %%
# Q41: Analyze payment installments
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART P
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>⭐</span> Customer Review Analysis
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Inspect satisfaction ratings, distribution of 1–5 review scores, and category ratings.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q42: Analyze Review Score Distribution <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">value_counts(), normalize=True</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the frequency count and percentage of each review score (1 to 5) in <code>reviews</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Score | Reviews | Percentage</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> pd.DataFrame({'Count': reviews['review_score'].value_counts(), 'Pct': reviews['review_score'].value_counts(normalize=True)*100})
#   </div>
# </div>

# %%
# Q42: Analyze review scores
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q43: Calculate Overall Average Review Score <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.mean() on review_score</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the overall mean customer review score across the entire platform.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Average review score = X.XX / 5.0</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> reviews['review_score'].mean()
#   </div>
# </div>

# %%
# Q43: Calculate average review score
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q44: Calculate Average Review Score by Product Category <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">merge, groupby('category')['review_score'].agg(['mean', 'count'])</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Merge reviews, orders, order_items, and products to determine the average customer rating for each product category (filter categories with >= 50 reviews).</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Category | Average Review | Review Count</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Filter agg_df[agg_df['count'] >= 50].sort_values(by='mean', ascending=False)
#   </div>
# </div>

# %%
# Q44: Calculate review score by product category
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART Q
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🚚</span> Delivery Logistics & Lead Time Analysis
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Compute delivery duration, late shipment rates, and monthly logistics latency.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q45: Calculate Delivery Duration in Days <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Datetime subtraction: (delivered - purchased).dt.total_seconds() / 86400</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Create a new column <code>delivery_days</code> representing the total days between purchase timestamp and customer delivery date.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>New column 'delivery_days' added to orders_clean</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> orders_clean['delivery_days'] = (orders_clean['order_delivered_customer_date'] - orders_clean['order_purchase_timestamp']).dt.total_seconds() / 86400
#   </div>
# </div>

# %%
# Q45: Calculate delivery duration
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q46: Calculate Average and Median Delivery Time <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.mean(), .median()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the platform-wide average delivery time and median delivery time in days.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Average delivery time: ? days | Median delivery time: ? days</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> orders_clean['delivery_days'].mean(), orders_clean['delivery_days'].median()
#   </div>
# </div>

# %%
# Q46: Calculate average delivery time
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q47: Identify Late Deliveries <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Boolean comparison: delivered > estimated</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Compare actual delivery date with estimated delivery date. Create a boolean column <code>is_late</code>, then report: total late orders, on-time orders, and late delivery percentage.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Late orders: ? | On-time orders: ? | Late percentage: ?%</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> orders_clean['is_late'] = orders_clean['order_delivered_customer_date'] > orders_clean['order_estimated_delivery_date']
#   </div>
# </div>

# %%
# Q47: Identify late deliveries
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q48: Calculate Average Delivery Time by Month <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">dt.to_period('M') or dt.strftime('%Y-%m'), groupby, mean()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Extract the purchase Year-Month and compute the average delivery time (in days) per month without using any charts.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Month | Orders | Average Delivery Days</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> orders_clean.groupby(orders_clean['order_purchase_timestamp'].dt.to_period('M'))['delivery_days'].mean()
#   </div>
# </div>

# %%
# Q48: Calculate average delivery time by month
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART R
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>📐</span> Statistical Analysis with NumPy
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Compute descriptive statistics, percentiles, variance, and investigate parametric skewness.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q49: Descriptive Statistics for Product Prices <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">np.mean, np.median, np.std, np.var, np.percentile, .describe()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Use NumPy and Pandas to compute: mean, median, min, max, standard deviation, variance, and 25th, 50th, 75th percentiles for product prices.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Statistical Summary Table for price</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> np.percentile(order_items['price'].dropna(), [25, 50, 75])
#   </div>
# </div>

# %%
# Q49: Calculate descriptive statistics for product prices
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q50: Descriptive Statistics for Freight Costs <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">NumPy/Pandas summary operations</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the full suite of descriptive statistics (mean, median, min, max, std, variance, percentiles) for <code>freight_value</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Statistical Summary Table for freight_value</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_items['freight_value'].agg(['mean', 'median', 'min', 'max', 'std', 'var'])
#   </div>
# </div>

# %%
# Q50: Calculate descriptive statistics for freight costs
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q51: Compare Mean vs. Median for Skewness <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Mean vs Median comparison, df.skew()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Compare the mean and median for <code>price, freight_value, payment_value</code>. Determine which columns exhibit positive (right) or negative (left) skewness.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Variable | Mean | Median | Difference | Skewness Direction</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> If Mean > Median, distribution is right-skewed by high-value outliers.
#   </div>
# </div>

# %%
# Q51: Compare mean vs median
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART S
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🎯</span> Outlier Detection using the IQR Method
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Calculate interquartile ranges, determine upper/lower fences, and quantify extreme values.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q52: Detect Price Outliers using IQR <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">quantile(0.25), quantile(0.75), IQR = Q3 - Q1</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate Q1, Q3, and IQR for <code>price</code>. Identify values outside [Q1 - 1.5*IQR, Q3 + 1.5*IQR]. Report: Q1, Q3, IQR, bounds, number of outliers, and outlier percentage.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Q1 | Q3 | IQR | Lower Bound | Upper Bound | Outliers Count | Outlier %</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Q1 = df['price'].quantile(0.25); Q3 = df['price'].quantile(0.75); IQR = Q3 - Q1
#   </div>
# </div>

# %%
# Q52: Detect price outliers using IQR
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q53: Detect Freight-Value Outliers using IQR <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">IQR outlier filtering formula</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Apply the IQR method to <code>freight_value</code>. Compute lower and upper fences and report the total count and percentage of freight outliers.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Q1 | Q3 | IQR | Lower Bound | Upper Bound | Outliers Count | Outlier %</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> freight_outliers = order_items[(order_items['freight_value'] < lower) | (order_items['freight_value'] > upper)]
#   </div>
# </div>

# %%
# Q53: Detect freight-value outliers
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q54: Compare Normal Records vs. Outliers <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Conditional comparison, boolean masking</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate and compare the mean and median prices of normal records vs outliers. Document what the differences reveal about marketplace pricing.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Metric | Normal Records | Outlier Records</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> normal_mean vs outlier_mean, normal_median vs outlier_median
#   </div>
# </div>

# %%
# Q54: Compare normal records with outliers
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART T
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🔬</span> Correlation Analysis Without Plotting
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Measure pairwise linear relationships between pricing, freight costs, and physical package dimensions.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q55: Investigate Price vs. Freight Value Correlation <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.corr(method='pearson')</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Calculate the Pearson correlation coefficient between <code>price</code> and <code>freight_value</code>. Characterize the relationship (Positive/Negative, Weak/Moderate/Strong).</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Correlation coefficient = 0.XX + interpretation</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> order_items[['price', 'freight_value']].corr()
#   </div>
# </div>

# %%
# Q55: Investigate price vs freight value
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q56: Investigate Product Dimensions vs. Freight Cost <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Pandas correlation matrix: df[['weight', 'length', 'height', 'width', 'freight']].corr()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Compute the correlation matrix between package attributes (<code>product_weight_g, product_length_cm, product_height_cm, product_width_cm</code>) and <code>freight_value</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Correlation Matrix Table</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Identify which dimension (e.g. weight) has the strongest correlation with freight
#   </div>
# </div>

# %%
# Q56: Investigate product dimensions vs freight cost
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART U
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>📈</span> Temporal & Trend Analysis Without Charts
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Track monthly revenue trajectories, peak periods, and month-over-month (MoM) growth rates.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q57: Analyze Monthly Revenue Trend <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">dt.to_period('M'), .groupby(), .sum(), .pct_change() * 100</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Aggregate total revenue by Year-Month and calculate the percentage change from the previous month.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Year-Month | Revenue | Change from Previous Month (%)</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> monthly_rev['Growth %'] = monthly_rev['Revenue'].pct_change() * 100
#   </div>
# </div>

# %%
# Q57: Analyze monthly revenue
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q58: Identify Highest and Lowest Revenue Months <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">.idxmax(), .idxmin(), .max(), .min()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Identify the specific calendar month that generated the highest revenue, and the month that generated the lowest revenue.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Highest revenue month: YYYY-MM ($X) | Lowest revenue month: YYYY-MM ($Y)</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> monthly_rev.loc[monthly_rev['Revenue'].idxmax()]
#   </div>
# </div>

# %%
# Q58: Identify the highest and lowest revenue months
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q59: Calculate Month-over-Month (MoM) Growth Table <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Table: Month | Revenue | MoM Growth (%)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Build a dedicated table showing monthly revenue along with exact MoM growth rates.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>(current - previous) / previous * 100</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Format percentages with round(2)
#   </div>
# </div>

# %%
# Q59: Calculate month-over-month growth
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART V
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>👥</span> Advanced Customer Profiling
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Segment customers by purchase frequency and construct customer lifetime value (CLV) metric tables.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q60: Customer Purchase Frequency: One-Time vs. Repeat <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">value_counts(), normalize=True</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Determine how many customers have placed only 1 order vs 2+ orders. Calculate the counts and percentages for each group.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Customer Type | Customers Count | Percentage</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> repeat_cust = (order_counts > 1).sum(); onetime_cust = (order_counts == 1).sum()
#   </div>
# </div>

# %%
# Q60: Calculate customer purchase frequency
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q61: Calculate Customer Monetary Value Table <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">groupby('customer_unique_id').agg(Total_Spent=..., AOV=..., Order_Count=...)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">For every unique customer, compute: total spending, average order value, and total order count.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Customer Analytical DataFrame (head(10))</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> cust_summary = merged_df.groupby('customer_unique_id').agg(...)
#   </div>
# </div>

# %%
# Q61: Calculate customer monetary value
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART W
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🎯</span> RFM Customer Segmentation
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Implement Recency, Frequency, and Monetary scoring to segment customers into strategic value tiers.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q62: Calculate Recency (R) per Customer <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">(max_dataset_date - max_customer_date).dt.days</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">For each customer, find their latest purchase date and calculate <code>days_since_last_purchase</code> relative to the dataset max date.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: customer_unique_id | recency_days</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> ref_date = orders_clean['order_purchase_timestamp'].max()
#   </div>
# </div>

# %%
# Q62: Calculate Recency
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q63: Calculate Frequency (F) per Customer <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">groupby('customer_unique_id')['order_id'].nunique()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">For each customer, compute the total number of distinct orders placed.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: customer_unique_id | frequency_orders</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> cust_freq = orders.groupby('customer_unique_id')['order_id'].nunique()
#   </div>
# </div>

# %%
# Q63: Calculate Frequency
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q64: Calculate Monetary Value (M) per Customer <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">groupby('customer_unique_id')['payment_value'].sum()</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">For each customer, compute the total cumulative monetary amount spent.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: customer_unique_id | monetary_value</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> cust_monetary = master_df.groupby('customer_unique_id')['payment_value'].sum()
#   </div>
# </div>

# %%
# Q64: Calculate Monetary value
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q65: Build the Consolidated RFM Table <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">pd.merge or pd.concat along axis=1</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Merge the Recency, Frequency, and Monetary metrics into a single unified <code>rfm_df</code>.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>DataFrame: customer_unique_id | recency | frequency | monetary</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> rfm = pd.DataFrame({'Recency': r, 'Frequency': f, 'Monetary': m})
#   </div>
# </div>

# %%
# Q65: Build an RFM table
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q66: Assign RFM Customer Segments <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">pd.qcut or custom numerical threshold rules with np.select / pd.cut</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Divide customers into strategic tiers using quantitative rules or quantiles (e.g. High-value, Loyal/Regular, Low-value, One-time). Document the analytical reasoning behind your thresholds.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Segment | Customer Count | % of Customers | Avg Spend</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Document your business segmentation rules clearly in comments
#   </div>
# </div>

# %%
# Q66: Create RFM customer groups
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART X
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>💡</span> Advanced Business Analytics
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Solve high-impact marketplace problems: revenue drivers, rating anomalies, and merchant efficiency.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q67: Top 10 Revenue Generating Categories & Share <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">groupby('category')['price'].sum(), % of total sum</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">List the top 10 product categories by gross revenue, along with their percentage contribution to total platform revenue.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Category | Revenue | % of Total Revenue</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> top10_cat['Pct'] = top10_cat['Revenue'] / total_revenue * 100
#   </div>
# </div>

# %%
# Q67: Which product categories generate the most revenue?
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q68: Top Rated Categories with Review Threshold <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">groupby + filter (count >= 50)</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Identify categories with the highest average customer review score, filtering for categories with at least 50 total reviews to avoid small-sample bias.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Category | Average Rating | Total Reviews</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> cat_reviews = df.groupby('category')['review_score'].agg(['mean', 'count']); cat_reviews[cat_reviews['count'] >= 50]
#   </div>
# </div>

# %%
# Q68: Which categories have the highest average ratings?
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q69: High-Revenue Categories with High Customer Ratings <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Multi-condition boolean filtering</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Identify product categories that achieve both high revenue (above median) AND high review ratings (above 4.0 stars).</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Category | Revenue | Average Review Score | Total Reviews</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> df[(df['Revenue'] > median_rev) & (df['Avg_Rating'] >= 4.0)]
#   </div>
# </div>

# %%
# Q69: Which categories have both high revenue and good reviews?
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q70: High-Volume Sellers with Low Review Ratings <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">Multi-condition boolean filtering on seller metrics</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Identify marketplace sellers who have generated substantial orders/revenue but suffer from substandard average review scores (< 3.5 stars with >= 20 reviews).</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: Seller ID | Orders | Revenue | Average Review Score</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Flag operational bottlenecks and merchant quality issues
#   </div>
# </div>

# %%
# Q70: Which sellers have high sales but poor reviews?
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART Y
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🏆</span> Business Performance Executive Summary
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Synthesize findings into an executive KPI scorecard.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #00695c; padding: 12px 18px; background: rgba(0, 105, 92, 0.05); border-radius: 0 10px 10px 0; margin: 22px 0 12px 0;">
#   <h3 style="margin: 0; color: #004d40; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 18px; font-weight: 700; display: flex; align-items: center; gap: 8px;">
#     <span>📍</span> Q71: Build the Overall Executive KPI Table <span style="background: #e0f2f1; color: #004d40; padding: 2px 8px; border-radius: 12px; font-size: 11px; font-weight: 600; margin-left: 8px;">pd.DataFrame summarizing all key platform metrics</span>
#   </h3>
#   <p style="margin: 8px 0 4px 0; color: #212121; font-size: 14px; line-height: 1.5;">Construct a comprehensive executive summary scorecard summarizing platform health across all operational domains.</p>
#   <div style="margin-top: 10px; background: #ffffff; padding: 10px 14px; border-radius: 6px; border: 1px solid #b2dfdb; font-size: 13px; color: #004d40;">
#     <b>📋 Expected Output / Structure:</b><br/><code>Table: KPI | Value (Total Customers, Orders, Products, Sellers, Revenue, AOV, Avg Review, Avg Delivery Days, Late %, Repeat %)</code>
#   </div>
#   <div style="margin-top: 8px; font-size: 12px; color: #00695c;">
#     💡 <b>Tip / Key Operations:</b> Consolidate results from Q15, Q16, Q17, Q25, Q26, Q43, Q46, Q47, Q60
#   </div>
# </div>

# %%
# Q71: Build an overall KPI table
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART Z
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🧠</span> Final Business Insights
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Interpret numerical results into actionable business intelligence across all 5 operational domains.</p>
# </div>

# %% [markdown]
# ### Analytical Interpretation Guidelines (Q72 – Q76)
#
# Document your conclusions in the spaces below using the numerical outputs computed in previous sections.
#
# ---
#
# #### **Q72. Customer Insights**
# - *What percentage of customers are repeat buyers? Is the business heavily dependent on acquisition or retention?*
# - *How concentrated is total spending among the top 10% or High-Value RFM segment?*
# - *What are the key behavioral patterns revealed by the RFM analysis?*
#
# *(Write your findings in the markdown space or code cell below)*

# %%
# Q72: Customer insights - optional code verification
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# #### **Q73. Product Insights**
# - *Which categories drive the majority of sales volume vs monetary revenue?*
# - *Which categories maintain high customer satisfaction vs frequent complaints?*
# - *Are expensive products necessarily more popular or do volume drivers come from budget items?*
#
# *(Write your findings in the space below)*

# %%
# Q73: Product insights - optional code verification
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# #### **Q74. Seller Insights**
# - *How concentrated is revenue across the top sellers?*
# - *Are high-volume merchants maintaining consistent fulfillment quality?*
# - *What operational interventions should be taken for high-sales, low-rating sellers?*
#
# *(Write your findings in the space below)*

# %%
# Q74: Seller insights - optional code verification
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# #### **Q75. Delivery Logistics Insights**
# - *What is the average delivery lead time, and how does median delivery time compare?*
# - *What is the percentage of late deliveries, and which calendar months experienced the worst shipping delays?*
# - *How do freight costs correlate with package weight and physical dimensions?*
#
# *(Write your findings in the space below)*

# %%
# Q75: Delivery insights - optional code verification
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# #### **Q76. Payment Insights**
# - *Which payment method dominates platform transaction volume and monetary value?*
# - *What is the typical customer installment behavior? Does installment usage correlate with order value?*
#
# *(Write your findings in the space below)*

# %%
# Q76: Payment insights - optional code verification
# Write your solution using Python / Pandas / NumPy below:

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 60%, #00897b 100%); padding: 22px 28px; border-radius: 14px; color: #ffffff; margin: 36px 0 20px 0; box-shadow: 0 6px 20px rgba(0, 77, 64, 0.25);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     PART FINAL
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 23px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🎓</span> Executive Conclusion & Analytical Synthesis
#   </h2>
#   <p style="margin: 8px 0 0 0; color: #e0f2f1; font-size: 14px; line-height: 1.5;">Deliver an executive conclusion addressing the 9 fundamental project discoveries.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #004d40 0%, #00695c 50%, #00897b 100%); padding: 26px 30px; border-radius: 14px; color: #ffffff; margin: 26px 0 20px 0; box-shadow: 0 8px 24px rgba(0, 77, 64, 0.35);">
#   <span style="background: rgba(255, 255, 255, 0.2); padding: 4px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1px; display: inline-block; margin-bottom: 8px;">
#     Portfolio Capstone Deliverable
#   </span>
#   <h2 style="margin: 0; color: #ffffff; font-family: 'Segoe UI', -apple-system, sans-serif; font-size: 24px; font-weight: 800; display: flex; align-items: center; gap: 10px;">
#     <span>🏆</span> Q77. Final Comprehensive Project Conclusion
#   </h2>
#   <p style="margin: 10px 0 0 0; color: #e0f2f1; font-size: 15px; line-height: 1.6;">
#     Synthesize all analytical findings into a structured conclusion addressing the 9 core discovery dimensions:
#   </p>
#   <ol style="margin: 12px 0 0 20px; color: #e0f2f1; line-height: 1.7; font-size: 14px;">
#     <li><b>Business Discoveries:</b> What are the foundational insights about marketplace scale and revenue generation?</li>
#     <li><b>Customer Patterns:</b> What does the analysis reveal about customer retention and acquisition?</li>
#     <li><b>Product & Category Performance:</b> Which categories are the engine of growth?</li>
#     <li><b>Delivery & Logistics Realities:</b> What are the major fulfillment and carrier bottlenecks?</li>
#     <li><b>Payment Dynamics:</b> How do consumers prefer to finance their purchases?</li>
#     <li><b>Statistical Discoveries:</b> What did parametric vs non-parametric metrics (mean vs median, IQR outliers) demonstrate?</li>
#     <li><b>Data Quality & Cleaning Impact:</b> What were the critical missingness, type-casting, and anomaly challenges?</li>
#     <li><b>Analytical Limitations:</b> What constraints existed in the data (e.g. timeframe, anonymized identifiers)?</li>
#     <li><b>Future Research & Modeling:</b> What predictive ML models (e.g. churn prediction, delivery delay estimation, LTV forecasting) should be built next?</li>
#   </ol>
# </div>

# %%
# Q77: Final project conclusion synthesis and summary reporting
# Write your solution using Python / Pandas / NumPy below:
