# %% [markdown]
# # 🐼 Pandas Basics for Machine Learning
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DebarghyaAich/Machine_Learning_Basics/blob/main/pandas.ipynb)
#
# Essential data exploration, cleaning, and transformation workflows using Pandas.

# %%
import pandas as pd
import numpy as np

print(f"Pandas version: {pd.__version__}")
print(f"NumPy version : {np.__version__}")

# %% [markdown]
# ## 1. Creating Series and DataFrames

# %%
# Create sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'Salary': [50000, 64000, 78000, 59000],
    'Department': ['IT', 'HR', 'Engineering', 'Marketing']
}

df = pd.DataFrame(data)
df
